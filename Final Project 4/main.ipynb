# %%
import parse_data as prs

df = prs.parse_data()
print( df )
# Out:
#      total_energy       t_in       h_in      t_out      h_out  windspeed  \
# 0            7000  18.977145  47.682691   5.922619  89.285714   6.083333
# 1           12950  18.859262  45.814280   5.566319  87.500000   5.784722
# 2           14750  18.488513  45.347219   4.856944  83.406250   5.614583
# 3           22520  18.857449  45.091948   3.431944  86.420139   6.277778
# 4           18910  19.778499  42.893877   2.665278  88.385417   7.770833
# ..            ...        ...        ...        ...        ...        ...
# 133         12250  23.940452  46.448866  12.570486  84.225694   4.208333
# 134         14460  23.760017  42.539191  11.568750  76.680556   4.114583
# 135         12450  23.181465  39.626588  11.563542  74.774306   1.350694
# 136         21620  23.831353  42.649774  14.923611  74.336806   1.850694
# 137         14930  24.264163  45.987942  17.195413  74.275229   2.041284
#
#      visibility
# 0     40.845238
# 1     37.229167
# 2     31.559028
# 3     35.149306
# ...

# %%
import descriptive as dsc

dsc.descriptive( df )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import descriptive as dsc
# ----> 3 dsc.descriptive( df )
#
# File ~/GitHub/DataAnalysisAssignments/Final Project 4/descriptive.py:43, in descriptive(df)
#      41 def descriptive( df ):
# ---> 43     final_descriptive_plot(df)
#
# File ~/GitHub/DataAnalysisAssignments/Final Project 4/descriptive.py:39, in final_descriptive_plot(df)
#      36 axs.flat[0].set_ylabel('Energy')
#      37 [ax.set_yticklabels([])  for ax in axs.flat[1:]]
# ---> 39 display_title('Correlations amongst main variables.', pref='Figure', num=1)
#
# NameError: name 'display_title' is not defined
